# %% [markdown]
# The file includes the code to import datasets from the Kagglehub service <br>
# **Do not** run it again for it will download the datasets

# %%
import kagglehub

# %%
path = kagglehub.dataset_download("artermiloff/steam-games-dataset")

print("Path to dataset files:", path)

# %%
path = kagglehub.dataset_download("muhammadaqeelkabir/steam-games-dataset-steamspy-api")

print("Path to dataset files:", path)

# %%
path = kagglehub.dataset_download("shoybhasan/most-played-games-steamdb")

print("Path to dataset files:", path)
